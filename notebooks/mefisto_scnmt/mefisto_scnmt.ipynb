# %%
# %load_ext autoreload
# %autoreload 2

import warnings

from data_loader import load_mouse_development

from famo.core import CORE
from famo.plotting import (
    plot_all_weights,
    plot_factor_correlation,
    plot_factor_covariate,
    plot_top_weights,
    plot_training_curve,
    plot_variance_explained,
    plot_weights,
)

warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
# Load mouse development data
mdata = load_mouse_development()

mdata["RNA"].obsm['umap'] = mdata["RNA"].obs[['UMAP1', 'UMAP2']].values
mdata["motif_met"].obsm['umap'] = mdata["motif_met"].obs[['UMAP1', 'UMAP2']].values
mdata["motif_acc"].obsm['umap'] = mdata["motif_acc"].obs[['UMAP1', 'UMAP2']].values

# %%
# Run model with MuData object
model = CORE(device="cuda")
model.fit(
    n_factors=7,
    data=mdata,
    likelihoods={
        "RNA": "Normal",
        "motif_met": "Normal",
        "motif_acc": "Normal",
    },
    factor_prior="GP",
    weight_prior="Horseshoe",
    covariates_key="umap",
    lr=0.005,
    early_stopper_patience=500,
    print_every=10,
    center_groups=True,
    scale_views=False,
    scale_groups=True,
    max_epochs=10000,
    save=False,
    save_path=None,
    init_factors="random",
    init_scale=0.1,
)
# Out:
# Setting up device...
# - No device id given. Using default device: 0
# - Running all computations on `cuda:0`
# Fitting model...
# - Checking compatibility of provided likelihoods with data.
#   - RNA: Normal
#   - motif_met: Normal
#   - motif_acc: Normal
# - Centering group_1/RNA...
# - Centering group_1/motif_met...
# - Centering group_1/motif_acc...
# alt.Chart(...)
# Initializing factors using `random` method...
# {'RNA': 0.794912559618442, 'motif_met': 1.102543720190779, 'motif_acc': 1.102543720190779}
# Decaying learning rate over 10000 iterations.
# Setting training seed to `2408131328`.
# Cleaning parameter store.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Run model with MuData object
#       2 model = CORE(device="cuda")
# ----> 3 model.fit(
#       4     n_factors=7,
#       5     data=mdata,
#       6     likelihoods={
#       7         "RNA": "Normal",
#       8         "motif_met": "Normal",
#       9         "motif_acc": "Normal",
#      10     },
#      11     factor_prior="GP",
#      12     weight_prior="Horseshoe",
#      13     covariates_key="umap",
#      14     lr=0.005,
#      15     early_stopper_patience=500,
#      16     print_every=10,
#      17     center_groups=True,
#      18     scale_views=False,
#      19     scale_groups=True,
#      20     max_epochs=10000,
#      21     save=False,
#      22     save_path=None,
#      23     init_factors="random",
#      24     init_scale=0.1,
#      25 )
#
# File /data/walter/famo/src/famo/core.py:649, in CORE.fit(self, data, n_factors, annotations, weight_prior, factor_prior, likelihoods, covariates_key, nonnegative_weights, nonnegative_factors, prior_penalty, batch_size, max_epochs, n_particles, lr, early_stopper_patience, print_every, plot_data_overview, scale_per_group, use_obs, use_var, save, save_path, init_factors, init_scale, gp_n_inducing, seed, **kwargs)
#     646 start_timer = time.time()
#     647 for i in range(max_epochs):
#     648     # import ipdb; ipdb.set_trace()
# --> 649     loss = step_fn()
#     650     self.train_loss_elbo.append(loss)
#     652     if i % print_every == 0:
#
# File /data/walter/famo/src/famo/core.py:619, in CORE.fit.<locals>.step_fn()
#     618 def step_fn():
# --> 619     return self._svi.step(tensor_dict)
#
# File /data/walter/miniconda3/envs/famo/lib/python3.12/site-packages/pyro/infer/svi.py:145, in SVI.step(self, *args, **kwargs)
#     143 # get loss and compute gradients
#     144 with poutine.trace(param_only=True) as param_capture:
# --> 145     loss = self.loss_and_grads(self.model, self.guide, *args, **kwargs)
#     147 params = set(
#     148     site["value"].unconstrained() for site in param_capture.trace.nodes.values()
#     149 )
#     151 # actually perform gradient steps
#     152 # torch.optim objects gets instantiated for any params that haven't been seen yet
#
# File /data/walter/miniconda3/envs/famo/lib/python3.12/site-packages/pyro/infer/trace_elbo.py:140, in Trace_ELBO.loss_and_grads(self, model, guide, *args, **kwargs)
#     138 loss = 0.0
#     139 # grab a trace from the generator
# --> 140 for model_trace, guide_trace in self._get_traces(model, guide, args, kwargs):
#     141     loss_particle, surrogate_loss_particle = self._differentiable_loss_particle(
#     142         model_trace, guide_trace
#     143     )
#     144     loss += loss_particle / self.num_particles
#
# File /data/walter/miniconda3/envs/famo/lib/python3.12/site-packages/pyro/infer/elbo.py:233, in ELBO._get_traces(self, model, guide, args, kwargs)
#     231 if self.vectorize_particles:
#     232     if self.max_plate_nesting == float("inf"):
# --> 233         self._guess_max_plate_nesting(model, guide, args, kwargs)
#     234     yield self._get_vectorized_trace(model, guide, args, kwargs)
#     235 else:
#
# File /data/walter/miniconda3/envs/famo/lib/python3.12/site-packages/pyro/infer/elbo.py:152, in ELBO._guess_max_plate_nesting(self, model, guide, args, kwargs)
#     150 # Ignore validation to allow model-enumerated sites absent from the guide.
#     151 with poutine.block():
# --> 152     guide_trace = poutine.trace(guide).get_trace(*args, **kwargs)
#     153     model_trace = poutine.trace(
#     154         poutine.replay(model, trace=guide_trace)
#     155     ).get_trace(*args, **kwargs)
#     156 guide_trace = prune_subsample_sites(guide_trace)
#
# File /data/walter/miniconda3/envs/famo/lib/python3.12/site-packages/pyro/poutine/trace_messenger.py:216, in TraceHandler.get_trace(self, *args, **kwargs)
#     208 def get_trace(self, *args, **kwargs) -> Trace:
#     209     """
#     210     :returns: data structure
#     211     :rtype: pyro.poutine.Trace
#    (...)
#     214     Calls this poutine and returns its trace instead of the function's return value.
#     215     """
# --> 216     self(*args, **kwargs)
#     217     return self.msngr.get_trace()
#
# File /data/walter/miniconda3/envs/famo/lib/python3.12/site-packages/pyro/poutine/trace_messenger.py:191, in TraceHandler.__call__(self, *args, **kwargs)
#     187 self.msngr.trace.add_node(
#     188     "_INPUT", name="_INPUT", type="args", args=args, kwargs=kwargs
#     189 )
#     190 try:
# --> 191     ret = self.fn(*args, **kwargs)
#     192 except (ValueError, RuntimeError) as e:
#     193     exc_type, exc_value, traceback = sys.exc_info()
#
# File /data/walter/miniconda3/envs/famo/lib/python3.12/site-packages/pyro/poutine/messenger.py:32, in _context_wrap(context, fn, *args, **kwargs)
#      25 def _context_wrap(
#      26     context: "Messenger",
#      27     fn: Callable,
#      28     *args: Any,
#      29     **kwargs: Any,
#      30 ) -> Any:
#      31     with context:
# ---> 32         return fn(*args, **kwargs)
#
# File /data/walter/miniconda3/envs/famo/lib/python3.12/site-packages/pyro/nn/module.py:450, in PyroModule.__call__(self, *args, **kwargs)
#     448 def __call__(self, *args, **kwargs):
#     449     with self._pyro_context:
# --> 450         result = super().__call__(*args, **kwargs)
#     451     if (
#     452         pyro.settings.get("validate_poutine")
#     453         and not self._pyro_context.active
#     454         and _is_module_local_param_enabled()
#     455     ):
#     456         self._check_module_local_param_usage()
#
# File /data/walter/miniconda3/envs/famo/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /data/walter/miniconda3/envs/famo/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /data/walter/famo/src/famo/model.py:772, in Variational.forward(self, data)
#     769 plates["factors"] = self.generative.get_plate("factors")
#     771 for group_name in current_group_names:
# --> 772     self.sample_dict[f"z_{group_name}"] = self.sample_factors[group_name](
#     773         f"z_{group_name}",
#     774         plates["factors"],
#     775         plates[f"samples_{group_name}"],
#     776         covariates=data[group_name].get("covariates", None),
#     777     )
#     779 for view_name in self.generative.n_features:
#     780     self.sample_dict[f"w_{view_name}"] = self.sample_weights[view_name](
#     781         f"w_{view_name}", plates["factors"], plates[f"features_{view_name}"]
#     782     )
#
# File /data/walter/famo/src/famo/model.py:723, in Variational._sample_component_gp(self, site_name, outer_plate, inner_plate, covariates, **kwargs)
#     714 with inner_plate as index:
#     715     f = pyro.sample(
#     716         f"f_{site_name[2:]}_{factor}",
#     717         gp.pyro_guide(
#    (...)
#     720         ),
#     721     )
# --> 723 self._sample_vector(
#     724     site_name + f"_{factor}",
#     725     inner_plate,
#     726 )
#
# File /data/walter/famo/src/famo/model.py:662, in Variational._sample_vector(self, site_name, plate, **kwargs)
#     660 def _sample_vector(self, site_name, plate, **kwargs):
#     661     with plate as index:
# --> 662         return self._sample(site_name, index=index, dim=plate.dim)
#
# File /data/walter/famo/src/famo/model.py:631, in Variational._sample(self, site_name, index, dim)
#     630 def _sample(self, site_name, index=None, dim=0):
# --> 631     if self.site_to_dist[site_name] in ["Normal", "LogNormal"]:
#     632         loc, scale = self._get_loc_and_scale(site_name)
#     633         if index is not None:
#
# KeyError: 'z_group_1_0'

# %%
plot_training_curve(model)
# Out:
# alt.Chart(...)

# %%
plot_variance_explained(model)
# Out:
# alt.HConcatChart(...)

# %%
plot_all_weights(model)
# Out:
# alt.HConcatChart(...)

# %%
plot_weights(model, "RNA")
# Out:
# alt.LayerChart(...)

# %%
plot_weights(model, "motif_met")
# Out:
# alt.LayerChart(...)

# %%
plot_weights(model, "motif_acc")
# Out:
# alt.LayerChart(...)

# %%
plot_factor_correlation(model)
# Out:
# alt.HConcatChart(...)

# %%
plot_top_weights(model, view="RNA")
# Out:
# alt.HConcatChart(...)

# %%
for factor in range(model.n_factors):
    plot_factor_covariate(model, factor + 1)
# Out:
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)
# alt.VConcatChart(...)

# %%
model.gps["group_1"].covar_module.outputscale
# Out:
# tensor([[0.0961],
#         [0.0848],
#         [0.1090],
#         [0.0971],
#         [0.1097],
#         [0.1149],
#         [0.0948]], device='cuda:0', grad_fn=<AddBackward0>)
