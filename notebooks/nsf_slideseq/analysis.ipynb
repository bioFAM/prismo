# %%
# %load_ext autoreload
# %autoreload 2

from data_loader import load_nsf_slideseq_subset_genes

from famo.core import CORE

# %%
adata = load_nsf_slideseq_subset_genes()

# %%
model = CORE(device="cuda:0")
model.fit(
    data=adata,
    n_factors=10,
    weight_prior="SnS",
    factor_prior="GP",
    likelihoods="Normal",
    covariates_obsm_key="spatial",
    max_epochs=3000,
    early_stopper_patience=500,
    lr=0.05,
    plot_data_overview=False,
    save=True,
    save_path="prismo_spatial_model",
    init_scale=0.1,
    gp_n_inducing=1000,
    seed=5432,
    batch_size=10000,
    print_every=1,
    nonnegative_factors=True,
    nonnegative_weights=True,
)

# prismo_model = load_model("prismo_model")
# Out:
# Setting up device...
# - Running all computations on `cuda:0`
# - Using provided likelihood for all views.
#   - view_1: Normal
# - Anchoring group_1/view_1...
# Initializing factors using `random` method...
# Decaying learning rate over 9000 iterations.
# Setting training seed to `5432`.
# Cleaning parameter store.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /data/walter/miniconda3/envs/famo/lib/python3.12/site-packages/pyro/poutine/trace_messenger.py:191, in TraceHandler.__call__(self, *args, **kwargs)
#     190 try:
# --> 191     ret = self.fn(*args, **kwargs)
#     192 except (ValueError, RuntimeError) as e:
#
# File /data/walter/miniconda3/envs/famo/lib/python3.12/site-packages/pyro/poutine/messenger.py:32, in _context_wrap(context, fn, *args, **kwargs)
#      31 with context:
# ---> 32     return fn(*args, **kwargs)
#
# ...
